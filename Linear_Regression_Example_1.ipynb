# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

# %% [markdown]
# **Load the Dataset**

# %%
df = pd.read_csv('USA_Housing.csv')
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             79545.46                 5.68                       7.01
# 1             79248.64                 6.00                       6.73
# 2             61287.07                 5.87                       8.51
# 3             63345.24                 7.19                       5.59
# 4             59982.20                 5.04                       7.84
# ...                ...                  ...                        ...
# 4995          60567.94                 7.83                       6.14
# 4996          78491.28                 7.00                       6.58
# 4997          63390.69                 7.25                       4.81
# 4998          68001.33                 5.53                       7.13
# 4999          65510.58                 5.99                       6.79
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   str
# dtypes: float64(6), str(1)
# memory usage: 273.6 KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count           5000.00              5000.00                    5000.00
# mean           68583.11                 5.98                       6.99
# std            10657.99                 0.99                       1.01
# min            17796.63                 2.64                       3.24
# 25%            61480.56                 5.32                       6.30
# 50%            68804.29                 5.97                       7.00
# 75%            75783.34                 6.65                       7.67
# max           107701.75                 9.52                      10.76
#
#        Avg. Area Number of Bedrooms  Area Population      Price
# count                       5000.00          5000.00    5000.00
# mean                           3.98         36163.52 1232072.65
# std                            1.23          9925.65  353117.63
# ...

# %%
df.describe().T
# Out:
#                                count       mean       std      min       25%  \
# Avg. Area Income             5000.00   68583.11  10657.99 17796.63  61480.56
# Avg. Area House Age          5000.00       5.98      0.99     2.64      5.32
# Avg. Area Number of Rooms    5000.00       6.99      1.01     3.24      6.30
# Avg. Area Number of Bedrooms 5000.00       3.98      1.23     2.00      3.14
# Area Population              5000.00   36163.52   9925.65   172.61  29403.93
# Price                        5000.00 1232072.65 353117.63 15938.66 997577.14
#
#                                     50%        75%        max
# Avg. Area Income               68804.29   75783.34  107701.75
# Avg. Area House Age                5.97       6.65       9.52
# Avg. Area Number of Rooms          7.00       7.67      10.76
# Avg. Area Number of Bedrooms       4.05       4.49       6.50
# Area Population                36199.41   42861.29   69621.71
# ...

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             79545.46                 5.68                       7.01
# 1             79248.64                 6.00                       6.73
# 2             61287.07                 5.87                       8.51
# 3             63345.24                 7.19                       5.59
# 4             59982.20                 5.04                       7.84
# ...                ...                  ...                        ...
# 4995          60567.94                 7.83                       6.14
# 4996          78491.28                 7.00                       6.58
# 4997          63390.69                 7.25                       4.81
# 4998          68001.33                 5.53                       7.13
# 4999          65510.58                 5.99                       6.79
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='str')

# %% [markdown]
# **Separate Features and Target Variable**

# %%
x = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]

y = df['Price']

# %%
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             79545.46                 5.68                       7.01
# 1             79248.64                 6.00                       6.73
# 2             61287.07                 5.87                       8.51
# 3             63345.24                 7.19                       5.59
# 4             59982.20                 5.04                       7.84
# ...                ...                  ...                        ...
# 4995          60567.94                 7.83                       6.14
# 4996          78491.28                 7.00                       6.58
# 4997          63390.69                 7.25                       4.81
# 4998          68001.33                 5.53                       7.13
# 4999          65510.58                 5.99                       6.79
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09         23086.80
# ...

# %%
y
# Out:
# 0      1059033.56
# 1      1505890.92
# 2      1058987.99
# 3      1260616.81
# 4       630943.49
#           ...
# 4995   1060193.79
# 4996   1482617.73
# 4997   1030729.58
# 4998   1198656.87
# 4999   1298950.48
# Name: Price, Length: 5000, dtype: float64

# %%
# ML related imports
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %% [markdown]
# **Split into Train and Test sets**

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
x_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2654          86690.87                 6.26                       6.68
# 2468          59866.95                 5.87                       5.90
# 290           74372.14                 6.56                       8.18
# 1463          61370.32                 6.53                       6.61
# 4508          52652.65                 5.69                       7.22
# ...                ...                  ...                        ...
# 4171          56610.64                 4.85                       7.56
# 599           70596.85                 6.55                       6.54
# 1361          55621.90                 3.74                       6.87
# 1547          63044.46                 5.94                       5.91
# 4959          75078.79                 7.64                       8.44
#
#       Avg. Area Number of Bedrooms  Area Population
# 2654                          3.23         42589.62
# ...

# %%
x_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1718          66775.00                 5.72                       7.80
# 2511          62184.54                 4.93                       7.43
# 345           73643.06                 6.77                       8.34
# 2521          61909.04                 6.23                       6.59
# 54            72942.71                 4.79                       7.32
# ...                ...                  ...                        ...
# 3412          57311.55                 5.26                       7.82
# 4020          76856.30                 5.51                       6.47
# 4635          59861.63                 8.10                       6.26
# 1700          59030.17                 6.16                       5.30
# 790           64506.79                 6.38                       7.55
#
#       Avg. Area Number of Bedrooms  Area Population
# 1718                          4.32         36788.98
# ...

# %%
y_train
# Out:
# 2654   1723729.66
# 2468   1039380.72
# 290    1648246.77
# 1463    824540.90
# 4508    928210.76
#           ...
# 4171    729641.74
# 599    1599478.99
# 1361   1102641.11
# 1547    865099.52
# 4959   2108376.17
# Name: Price, Length: 3500, dtype: float64

# %%
y_test
# Out:
# 1718   1251688.62
# 2511    873048.32
# 345    1696977.66
# 2521   1063964.29
# 54      948788.28
#           ...
# 3412    704375.87
# 4020   1254938.14
# 4635   1434323.82
# 1700    534077.46
# 790    1427202.28
# Name: Price, Length: 1500, dtype: float64

# %% [markdown]
# **Train the Linear Regression Model**

# %%
model = LinearRegression() # Untrained model (Not yet fitted to the data)
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train) # Train the model i.e. fit the model to the training data (Learn the coefficients)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# -2641372.667264207

# %%
feature_importance = [float(f'{value:f}') for value in model.coef_]
print('Coefficients: \n', feature_importance)
# Out:
# Coefficients:
#  [21.617635, 165221.119872, 121405.376595, 1318.718781, 15.225196]

# %%
# Feature importance in a more readable format
feature_importance_df = pd.DataFrame(data=feature_importance, index=x.columns, columns=['Feature Importance'])
feature_importance_df.sort_values(by='Feature Importance', ascending=False)
# Out:
#                               Feature Importance
# Avg. Area House Age                    165221.12
# Avg. Area Number of Rooms              121405.38
# Avg. Area Number of Bedrooms             1318.72
# Avg. Area Income                           21.62
# Area Population                            15.23

# %%
feature_importance_df.sort_values(by='Feature Importance', ascending=False).plot(
    kind='bar', figsize=(8, 6), title='Feature Importance', legend=False, ylabel='Coefficient Value', xlabel='Feature', color='salmon')

plt.xticks(rotation=75)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Evaluate the Model**

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1258934.89519475,  822694.63395327, 1742214.39533362, ...,
#        1452640.96481227,  645797.13020585, 1364943.76220545],
#       shape=(1500,))

# %%
print('mean_squared_error: ', mean_squared_error(y_test, y_pred))
# Out:
# mean_squared_error:  10169125565.18005

# %%
print('r2_score: ', r2_score(y_test, y_pred))
# Out:
# r2_score:  0.9185060945460716

# %%
plt.scatter(y_test, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig('Housing_Model.png')
plt.show()

# %% [markdown]
# **Make a prediction**

# %%
x_new = [[58204.22309, 6.301814027, 7.375616033, 5.41, 46663.40274], 
         [62085.2764, 5.739410844, 7.091808104, 5.49, 44922.1067]]

actual_price = [1059033.312, 1030591.429]
predicted_price = model.predict(x_new)

for i in range(len(x_new)):
    print(f'Actual Price: ${actual_price[i]:,.2f}')
    print(f'Predicted Price: ${predicted_price[i]:,.2f}')
    print('---' * 10)
# Out:
# Actual Price: $1,059,033.31
# Predicted Price: $1,271,090.89
# ------------------------------
# Actual Price: $1,030,591.43
# Predicted Price: $1,201,207.32
# ------------------------------
# c:\DL_ML_Rahul\ML_Demo_26\myvenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Save the Model**

# %%
file_name = 'housing_model.pkl'
joblib.dump(model, file_name) # Serialize the model and save it to a file
print(f'Model saved to {file_name}')
# Out:
# Model saved to housing_model.pkl

# %% [markdown]
# **Load the Saved Model**

# %%
file_name = 'housing_model.pkl'
loaded_model = joblib.load(file_name) # Deserialize the model from the file
print(f'Model loaded from {file_name}')
# Out:
# Model loaded from housing_model.pkl

# %%
x_new = [[88244.61487, 6.548375433, 8.765481292, 3.36, 25791.99499], 
         [79504.65959, 6.505108814, 7.554076285, 4.1, 42677.28492],
         [58765.0402, 5.506579633, 4.882380596, 4.12, 30997.43904]
         ]

actual_price = [1788285.239, 1741105.641,647691.8352]
predicted_price = loaded_model.predict(x_new)

for i in range(len(x_new)):
    print(f'Actual Price: {actual_price[i]:,.2f}')
    print(f'Predicted Price: {predicted_price[i]:,.2f}')
    print('---' * 10)
# Out:
# Actual Price: 1,788,285.24
# Predicted Price: 1,809,492.75
# ------------------------------
# Actual Price: 1,741,105.64
# Predicted Price: 1,724,393.64
# ------------------------------
# Actual Price: 647,691.84
# Predicted Price: 608,914.22
# ------------------------------
# c:\DL_ML_Rahul\ML_Demo_26\myvenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Hyperparameter Tuning**

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV

# %%
import multiprocessing
multiprocessing.cpu_count()
# Out:
# 16

# %%
# Using GridSearchCV to find the best alpha for Ridge Regression
param_grid = {
    'alpha': [0.01, 0.1, 0.2, 0.5, 0.8, 1.0, 10.0, 100.0, 1000.0]
}

ridge = Ridge()

grid_search_ridge = GridSearchCV(estimator=ridge, param_grid=param_grid, cv=5, scoring='r2',  n_jobs=-1)
grid_search_ridge.fit(x_train, y_train)

best_ridge_model = grid_search_ridge.best_estimator_
best_r2_score = grid_search_ridge.best_score_
print(f'Best Alpha for Ridge Regression: {best_ridge_model.alpha}')
print(f'Best R2 Score from Grid Search: {best_r2_score:.4f}')

feature_importance = [float(f'{value:f}') for value in best_ridge_model.coef_]
feature_importance_df = pd.DataFrame(data=feature_importance, index=x.columns, columns=['Feature Importance'])
feature_importance_df.sort_values(by='Feature Importance', ascending=False)
# Out:
# Best Alpha for Ridge Regression: 1.0
# Best R2 Score from Grid Search: 0.9173
#                               Feature Importance
# Avg. Area House Age                    165170.96
# Avg. Area Number of Rooms              121360.43
# Avg. Area Number of Bedrooms             1336.46
# Avg. Area Income                           21.62
# Area Population                            15.23

# %%
# Using GridSearchCV to find the best alpha for Lasso Regression
lasso = Lasso()
grid_search_lasso = GridSearchCV(estimator=lasso, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search_lasso.fit(x_train, y_train)
best_lasso_model = grid_search_lasso.best_estimator_
best_r2_score_lasso = grid_search_lasso.best_score_
print(f'Best Alpha for Lasso Regression: {best_lasso_model.alpha}')
print(f'Best R2 Score from Grid Search: {best_r2_score_lasso:.4f}')

feature_importance = [float(f'{value:f}') for value in best_lasso_model.coef_]
feature_importance_df = pd.DataFrame(data=feature_importance, index=x.columns, columns=['Feature Importance'])
feature_importance_df.sort_values(by='Feature Importance', ascending=False)
# Out:
# Best Alpha for Lasso Regression: 100.0
# Best R2 Score from Grid Search: 0.9173
#                               Feature Importance
# Avg. Area House Age                    165117.30
# Avg. Area Number of Rooms              121324.14
# Avg. Area Number of Bedrooms             1285.36
# Avg. Area Income                           21.62
# Area Population                            15.23

# %% [markdown]
# **Hyperpatemeter Tuning with Normalization**

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
pipeline1 = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LinearRegression())
])

pipeline1.fit(x_train, y_train)
y_pred_pipeline1 = pipeline1.predict(x_test)
print('R2 Score for Pipeline with Linear Regression: ', r2_score(y_test, y_pred_pipeline1))
# Out:
# R2 Score for Pipeline with Linear Regression:  0.9185060945460737

# %%
param_grid = {
    'alpha': [0.01, 0.1, 0.2, 0.5, 0.8, 1.0, 10.0, 100.0, 1000.0]
}
pipeline_ridge = Pipeline([
    ('scaler', StandardScaler()),
    ('model', Ridge())
])
grid_search_ridge_pipeline = GridSearchCV(estimator=pipeline_ridge, param_grid={'model__alpha': param_grid['alpha']}, cv=5, scoring='r2', n_jobs=-1)
grid_search_ridge_pipeline.fit(x_train, y_train)
best_ridge_pipeline = grid_search_ridge_pipeline.best_estimator_
best_ridge_pipeline_alpha = grid_search_ridge_pipeline.best_params_['model__alpha']
print(f'Best Alpha for Ridge Regression Pipeline: {best_ridge_pipeline_alpha}')
y_pred_ridge_pipeline = best_ridge_pipeline.predict(x_test)
print('R2 Score for Ridge Regression Pipeline: ', r2_score(y_test, y_pred_ridge_pipeline))
# Out:
# Best Alpha for Ridge Regression Pipeline: 1.0
# R2 Score for Ridge Regression Pipeline:  0.9185084332586795

# %%
pipeline_lasso = Pipeline([
    ('scaler', StandardScaler()),
    ('model', Lasso())
])
grid_search_lasso_pipeline = GridSearchCV(estimator=pipeline_lasso, param_grid={'model__alpha': param_grid['alpha']}, cv=5, scoring='r2', n_jobs=-1)
grid_search_lasso_pipeline.fit(x_train, y_train)
best_lasso_pipeline = grid_search_lasso_pipeline.best_estimator_
best_lasso_pipeline_alpha = grid_search_lasso_pipeline.best_params_['model__alpha']
print(f'Best Alpha for Lasso Regression Pipeline: {best_lasso_pipeline_alpha}')
y_pred_lasso_pipeline = best_lasso_pipeline.predict(x_test)
print('R2 Score for Lasso Regression Pipeline: ', r2_score(y_test, y_pred_lasso_pipeline))
# Out:
# Best Alpha for Lasso Regression Pipeline: 100.0
# R2 Score for Lasso Regression Pipeline:  0.9185089504572718

# %% [markdown]
# **Mixing L1 and L2 Regularization in Training activity**

# %%
param_grid = [
    {
        'model' : [Lasso()],
        'model__alpha': [0.01, 0.1, 1.0, 10.0, 100.0, 1000.0],
    },
    {
        'model' : [Ridge()],
        'model__alpha': [0.01, 0.1, 0.2, 0.5, 0.8, 1.0, 10.0, 100.0, 1000.0],
    }
]

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', None)  # Placeholder, will be set by GridSearchCV
])

grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=20, scoring='r2', n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
best_model_type = type(best_model.named_steps['model']).__name__
best_model_alpha = best_model.named_steps['model'].alpha
print(f'Best Model: {best_model_type} with Alpha: {best_model_alpha}')
y_pred = best_model.predict(x_test)
print('R2 Score for Best Model Pipeline: ', r2_score(y_test, y_pred))
# Out:
# Fitting 20 folds for each of 15 candidates, totalling 300 fits
# Best Model: Ridge with Alpha: 10.0
# R2 Score for Best Model Pipeline:  0.9185222301811565

# %%
file_name = 'housing_model.pkl'
joblib.dump(best_model, file_name) # Serialize the model and save it to a file
print(f'Model saved to {file_name}')
# Out:
# Model saved to housing_model.pkl

# %%
file_name = 'housing_model.pkl'
loaded_model = joblib.load(file_name) # Deserialize the model from the file
print(f'Model loaded from {file_name}')
# Out:
# Model loaded from housing_model.pkl

# %%
x_new = [[88244.61487, 6.548375433, 8.765481292, 3.36, 25791.99499], 
         [79504.65959, 6.505108814, 7.554076285, 4.1, 42677.28492],
         [58765.0402, 5.506579633, 4.882380596, 4.12, 30997.43904]
         ]

actual_price = [1788285.239, 1741105.641,647691.8352]
predicted_price = loaded_model.predict(x_new)

for i in range(len(x_new)):
    print(f'Actual Price: {actual_price[i]:,.2f}')
    print(f'Predicted Price: {predicted_price[i]:,.2f}')
    print('---' * 10)
# Out:
# Actual Price: 1,788,285.24
# Predicted Price: 1,807,528.24
# ------------------------------
# Actual Price: 1,741,105.64
# Predicted Price: 1,722,923.55
# ------------------------------
# Actual Price: 647,691.84
# Predicted Price: 610,932.94
# ------------------------------
# c:\DL_ML_Rahul\ML_Demo_26\myvenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
